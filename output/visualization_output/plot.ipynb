# %%
import pandas as pd 
import matplotlib.pyplot as plt

from datetime import datetime
from pathlib import Path

# %% [markdown]
# # First Part - Set Target CSV results to analyze

# %%
print(Path().resolve().parent)
# Out:
# C:\Users\andre\Repositories\FTZ_model_2.0\output

# %%
df_path = Path().resolve().parent/ "coevolution_results_6_node_nested_graph_env_1_20251007.csv"

# %%
df = pd.read_csv(df_path)
